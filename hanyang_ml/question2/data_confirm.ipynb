# %% [markdown]
# # 주어진 파일 확인

# %%
import pandas as pd
import missingno
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## all_buildings_meta_data

# %%
data = pd.read_csv("./data/all_buildings_meta_data.csv")
data
# Out:
#                      uid         dataend       datastart  energystarscore  \
# 0      PrimClass_Everett  31/12/12 23:00  01/01/12 00:00              NaN
# 1     UnivClass_Clifford  31/12/15 23:00  01/01/15 00:00              NaN
# 2       Office_Elizabeth  31/12/12 23:00  01/01/12 00:00              NaN
# 3           Office_Ellie  31/12/12 23:00  01/01/12 00:00              NaN
# 4    PrimClass_Elisabeth  31/12/12 23:00  01/01/12 00:00              NaN
# ..                   ...             ...             ...              ...
# 502          Office_Lane  30/11/15 23:00  01/12/14 00:00              NaN
# 503       Office_Cameron  31/12/15 23:00  01/01/15 00:00              NaN
# 504          UnivLab_Lea  30/11/15 23:00  01/12/14 00:00              NaN
# 505       UnivLab_Carlos  31/12/15 23:00  01/01/15 00:00              NaN
# 506        UnivLab_Aoife  31/12/15 23:00  01/01/15 00:00              NaN
#
#       heatingtype             industry mainheatingtype  numberoffloors  \
# ...

# %%
data[data["newweatherfilename"] == "weather2.csv"]
# Out:
#                     uid         dataend       datastart  energystarscore  \
# 1    UnivClass_Clifford  31/12/15 23:00  01/01/15 00:00              NaN
# 5       Office_Cristina  31/12/15 23:00  01/01/15 00:00              NaN
# 50     UnivDorm_Claudia  31/12/15 23:00  01/01/15 00:00              NaN
# 60       UnivDorm_Carla  31/12/15 23:00  01/01/15 00:00              NaN
# 61     UnivClass_Camden  31/12/15 23:00  01/01/15 00:00              NaN
# ..                  ...             ...             ...              ...
# 478      UnivLab_Carley  31/12/15 23:00  01/01/15 00:00              NaN
# 495      UnivLab_Carole  31/12/15 23:00  01/01/15 00:00              NaN
# 499    UnivDorm_Cecilia  31/12/15 23:00  01/01/15 00:00              NaN
# 503      Office_Cameron  31/12/15 23:00  01/01/15 00:00              NaN
# 505      UnivLab_Carlos  31/12/15 23:00  01/01/15 00:00              NaN
#
#     heatingtype   industry mainheatingtype  numberoffloors  occupants  \
# ...

# %%
data[data["uid"] == "UnivClass_Alfredo"]
# Out:
#                    uid         dataend       datastart  energystarscore  \
# 346  UnivClass_Alfredo  31/12/15 23:00  01/01/15 00:00              NaN
#
#     heatingtype   industry mainheatingtype  numberoffloors  occupants  \
# 346         NaN  Education             NaN             NaN        NaN
#
#      primaryspaceusage rating     sqft          sqm         subindustry  \
# 346  College Classroom    NaN  90903.0  8445.161409  College/University
#
#             timezone yearbuilt nickname primaryspaceuse_abbrev  \
# 346  America/Phoenix       NaN  Alfredo              UnivClass
#
#     newweatherfilename
# 346       weather0.csv

# %%
data.count()
# Out:
# uid                       507
# dataend                   507
# datastart                 507
# energystarscore            26
# heatingtype               124
# industry                  507
# mainheatingtype           122
# numberoffloors            124
# occupants                 105
# primaryspaceusage         507
# rating                    131
# sqft                      507
# sqm                       507
# subindustry               507
# timezone                  507
# yearbuilt                 313
# nickname                  507
# primaryspaceuse_abbrev    507
# newweatherfilename        507
# dtype: int64

# %%
data.describe()
# Out:
#        energystarscore  numberoffloors    occupants          sqft  \
# count        26.000000      124.000000   105.000000  5.070000e+02
# mean         67.269231        3.766129   713.647619  9.475671e+04
# std          26.760505        3.052678   847.602569  1.243108e+05
# min           3.000000        1.000000     0.000000  4.298000e+03
# 25%          49.000000        2.000000   230.000000  3.136550e+04
# 50%          79.000000        2.000000   383.000000  6.666083e+04
# 75%          87.750000        6.000000   909.000000  1.214553e+05
# max         100.000000       16.000000  4144.000000  1.675720e+06
#
#                  sqm
# count     507.000000
# mean     8803.185495
# std     11548.848433
# min       399.297094
# 25%      2913.949046
# 50%      6193.000000
# 75%     11283.570160
# max    155679.415200

# %%
missingno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 날씨 데이터 확인

# %%
weather0 = pd.read_csv("./data/weather0.csv")
weather0
# Out:
#                 timestamp   TimeMST  TemperatureC  Dew PointC  Humidity  \
# 0     2015-01-01 00:51:00  12:51 AM           2.8        -0.6      79.0
# 1     2015-01-01 01:47:00   1:47 AM           3.0        -1.0      75.0
# 2     2015-01-01 01:51:00   1:51 AM           2.8        -0.6      79.0
# 3     2015-01-01 02:51:00   2:51 AM           2.8        -1.1      76.0
# 4     2015-01-01 03:51:00   3:51 AM           2.2        -0.6      82.0
# ...                   ...       ...           ...         ...       ...
# 8994  2015-12-31 19:51:00   7:51 PM          12.2        -6.1      28.0
# 8995  2015-12-31 20:51:00   8:51 PM          11.7        -6.7      27.0
# 8996  2015-12-31 21:51:00   9:51 PM          10.0        -6.7      31.0
# 8997  2015-12-31 22:51:00  10:51 PM           9.4        -6.1      33.0
# 8998  2015-12-31 23:51:00  11:51 PM           7.2        -5.6      40.0
#
#       Sea Level PressurehPa  VisibilityKm Wind Direction Wind SpeedKm/h  \
# ...

# %%
weather2 = pd.read_csv("./data/weather2.csv")
weather2
# Out:
#                  timestamp  Conditions              DateUTC<br />  Dew PointC  \
# 0      2015-01-01 00:56:00    Overcast  2015-01-01 05:56:00<br />       -15.0
# 1      2015-01-01 01:56:00    Overcast  2015-01-01 06:56:00<br />       -14.4
# 2      2015-01-01 02:56:00    Overcast  2015-01-01 07:56:00<br />       -14.4
# 3      2015-01-01 03:56:00    Overcast  2015-01-01 08:56:00<br />       -14.4
# 4      2015-01-01 04:56:00    Overcast  2015-01-01 09:56:00<br />       -14.4
# ...                    ...         ...                        ...         ...
# 10909  2015-12-31 17:56:00  Light Snow  2015-12-31 22:56:00<br />        -1.0
# 10910  2015-12-31 18:56:00  Light Snow  2015-12-31 23:56:00<br />        -2.0
# 10911  2015-12-31 19:56:00  Light Snow  2016-01-01 00:56:00<br />        -1.0
# 10912  2015-12-31 20:56:00  Light Snow  2016-01-01 01:56:00<br />        -1.0
# 10913  2015-12-31 21:56:00  Light Snow  2016-01-01 02:56:00<br />        -2.0
#
# ...

# %%
weather4 = pd.read_csv("./data/weather4.csv")
weather4
# Out:
#                  timestamp Conditions              DateUTC<br />  Dew PointC  \
# 0      2015-01-01 00:53:00      Clear  2015-01-01 05:53:00<br />       -12.2
# 1      2015-01-01 01:53:00      Clear  2015-01-01 06:53:00<br />       -13.3
# 2      2015-01-01 02:53:00      Clear  2015-01-01 07:53:00<br />       -13.9
# 3      2015-01-01 03:53:00      Clear  2015-01-01 08:53:00<br />       -13.9
# 4      2015-01-01 04:53:00      Clear  2015-01-01 09:53:00<br />       -13.9
# ...                    ...        ...                        ...         ...
# 11129  2015-12-31 21:53:00   Overcast  2016-01-01 02:53:00<br />        -1.1
# 11130  2015-12-31 22:29:00   Overcast  2016-01-01 03:29:00<br />        -1.7
# 11131  2015-12-31 22:40:00   Overcast  2016-01-01 03:40:00<br />        -2.2
# 11132  2015-12-31 22:53:00   Overcast  2016-01-01 03:53:00<br />        -2.2
# 11133  2015-12-31 23:53:00   Overcast  2016-01-01 04:53:00<br />        -2.2
#
# ...

# %% [markdown]
# # 기타 데이터 확인

# %%
data2 = pd.read_csv("./data/Office_Autumn.csv")
data2
# Out:
#                 timestamp  Office_Autumn
# 0     2015-01-01 00:00:00         160.15
# 1     2015-01-01 01:00:00         162.95
# 2     2015-01-01 02:00:00         157.14
# 3     2015-01-01 03:00:00         266.57
# 4     2015-01-01 04:00:00         278.86
# ...                   ...            ...
# 8755  2015-12-31 19:00:00         171.21
# 8756  2015-12-31 20:00:00         175.82
# 8757  2015-12-31 21:00:00          47.28
# 8758  2015-12-31 22:00:00         187.35
# 8759  2015-12-31 23:00:00         191.62
#
# [8760 rows x 2 columns]

# %%
data3 = pd.read_csv("./data/Office_Cecelia.csv")
data3
# Out:
#                 timestamp  Office_Cecelia
# 0     2015-01-01 00:00:00           8.150
# 1     2015-01-01 01:00:00           8.025
# 2     2015-01-01 02:00:00           7.875
# 3     2015-01-01 03:00:00           7.700
# 4     2015-01-01 04:00:00           7.825
# ...                   ...             ...
# 8755  2015-12-31 19:00:00           8.175
# 8756  2015-12-31 20:00:00           8.025
# 8757  2015-12-31 21:00:00           7.975
# 8758  2015-12-31 22:00:00           7.875
# 8759  2015-12-31 23:00:00           8.050
#
# [8760 rows x 2 columns]

# %%
data2 = pd.read_csv("./data/UnivDorm_Cian.csv")
data2
# Out:
#                 timestamp  UnivDorm_Cian
# 0     2015-01-01 00:00:00         13.775
# 1     2015-01-01 01:00:00         14.050
# 2     2015-01-01 02:00:00         13.725
# 3     2015-01-01 03:00:00         14.100
# 4     2015-01-01 04:00:00         13.500
# ...                   ...            ...
# 8755  2015-12-31 19:00:00         11.600
# 8756  2015-12-31 20:00:00         11.500
# 8757  2015-12-31 21:00:00         11.425
# 8758  2015-12-31 22:00:00         11.775
# 8759  2015-12-31 23:00:00         11.600
#
# [8760 rows x 2 columns]
